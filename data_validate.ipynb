# %%
import pandas as pd

# %%
exp_df = pd.read_csv(r'C:\Users\birap\OneDrive\Desktop\Projects\shanky_dashboard\cleaned_data\cleaned_exports.csv')

# %%
exp_df.head(1)
# Out:
#   CT_TYPE  CC_CODE                                         CC_DESC_AR  \
# 0    ISI4        1  أنشطة زراعة المحاصيل والإنتاج الحيواني والصيد ...
#
#                                           CC_DESC_EN COMMODTIY_TYPE  \
# 0  Crop and animal production, hunting and relate...              H
#
#    COMMODTIY_CODE  COMM_NAME_AR      COMM_NAME_EN       2023     2024
# 0         1012910  خيول للرياضة  Horses for sport  1817329.0  11227.0

# %%
df = exp_df[exp_df["CC_DESC_EN"] == 'Manufacture of furniture']

# %%
df.head(2)
# Out:
#      CT_TYPE  CC_CODE   CC_DESC_AR                CC_DESC_EN COMMODTIY_TYPE  \
# 5629    ISI4       31  صُنع الأثاث  Manufacture of furniture              H
# 5630    ISI4       31  صُنع الأثاث  Manufacture of furniture              H
#
#       COMMODTIY_CODE                                       COMM_NAME_AR  \
# 5629        94014100                                             من خشب
# 5630        94014900  مقاعد غير خشبية قابلة للتحويل إلى أسرة، عدا مق...
#
#                                            COMM_NAME_EN      2023       2024
# 5629                                            Of wood   80815.0    42420.0
# 5630  Non-wooden seats convertible into beds, excl c...  299462.0  1192325.0

# %%
df['2023'].astype(float).sum()
# Out:
# np.float64(185264339.0)
